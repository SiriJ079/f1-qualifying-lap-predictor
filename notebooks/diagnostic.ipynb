# %%
from pathlib import Path

PROJECT_ROOT = Path(__file__).resolve().parent.parent.parent if "__file__" in dir() else Path.cwd().parent
features_path = PROJECT_ROOT / "data" / "features" / "qualifying_features.parquet"

print("Looking for file at:", features_path)
print("File exists:", features_path.exists())
print("\nContents of data/features/:")
feature_dir = PROJECT_ROOT / "data" / "features"
if feature_dir.exists():
    for f in feature_dir.iterdir():
        print(" -", f.name)
else:
    print(" ⚠️ data/features/ directory does not exist at all")
# Out:
# Looking for file at: c:\Users\siraj\OneDrive\Project Portfolio\f1-qualifying-lap-predictor\data\features\qualifying_features.parquet
# File exists: True
#
# Contents of data/features/:
#  - .gitkeep
#  - qualifying_features.parquet

# %%
from pathlib import Path
import src.models.data_split as ds

print("cwd:", Path.cwd())
print("data_split:", ds.__file__)
print("FEATURES_PATH:", ds.FEATURES_PATH)
print("Exists:", ds.FEATURES_PATH.exists())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from pathlib import Path
# ----> 2 import src.models.data_split as ds
#       3
#       4 print("cwd:", Path.cwd())
#       5 print("data_split:", ds.__file__)
#
# ModuleNotFoundError: No module named 'src.models'

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# c:\Users\siraj\OneDrive\Project Portfolio\f1-qualifying-lap-predictor\notebooks
